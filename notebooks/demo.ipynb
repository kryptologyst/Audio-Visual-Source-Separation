# %% [markdown]
# # Audio-Visual Source Separation Demo
#
# This notebook demonstrates the audio-visual source separation model with dummy data.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
from pathlib import Path

# Import our modules
from src.models.av_separation import AVSourceSeparator
from src.utils.device import get_device, set_seed
from src.utils.audio import normalize_audio
from src.utils.video import detect_faces, preprocess_frame
from src.viz.visualizer import AVVisualizer
from src.eval.metrics import AVSourceSeparationEvaluator
